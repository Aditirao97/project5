# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("placement_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.head(1)
# Out:
#    cgpa  package
# 0  6.89     3.26

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('lpa')
plt.ylabel('cgp')
plt.show()

# %%
X=df[['cgpa']]

# %%
Y=df[['package']]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test.iloc[0]
# Out:
# cgpa    8.58
# Name: 112, dtype: float64

# %%
lr.predict(X_test.iloc[[0]])
# Out:
# array([[3.89111601]])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('lpa')
plt.ylabel('cgp')
plt.show()

# %%
m=lr.coef_

# %%
b=lr.intercept_

# %%
print("slope",m)
# Out:
# slope [[0.55795197]]

# %%
print("Intercept",b)
# Out:
# Intercept [-0.89611192]

# %%
Y=m*8.58+b
print(Y)
# Out:
# [[3.89111601]]

# %%
# creatying new data set

# %%
data = {'mask':[34,37,39,40,58,48,59,59,60],
        'placement':[3,4,5,6,7,8,9,10,13]
       }

# %%
df1=pd.DataFrame(data)

# %%
df1
# Out:
#    mask  placement
# 0    34          3
# 1    37          4
# 2    39          5
# 3    40          6
# 4    58          7
# 5    48          8
# 6    59          9
# 7    59         10
# 8    60         13

# %%
X1=df1[['mask']]

# %%
Y1=df1[['placement']]

# %%
plt.scatter(X1,Y1)
plt.xlabel('marks')
plt.ylabel('placement')
plt.show()

# %%
X1_train,X1_test,Y1_train,Y1_test=train_test_split(X1,Y1,test_size=0.2,random_state=2)

# %%
model=LinearRegression()

# %%
model.fit(X1_train,Y1_train)
# Out:
# LinearRegression()

# %%
X1_test.iloc[0]
# Out:
# mask    58
# Name: 4, dtype: int64

# %%
model.predict(X1_test.iloc[[0]])
# Out:
# array([[10.44251969]])

# %%
plt.scatter(X1,Y1)
plt.plot(X1_test,model.predict(X1_test))
plt.xlabel('marks')
plt.ylabel('placement')
plt.show()
